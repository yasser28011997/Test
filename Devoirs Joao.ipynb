# %% [markdown]
# <a href="https://colab.research.google.com/github/yasser28011997/Test/blob/main/Devoirs%20Joao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
import struct
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import functools
import pandas as pd

# %%
from pymicro.file.file_utils import HST_info, HST_read, HST_write

# %%
# !ls
# Out:
# data_reduced.raw       labels.reduced.raw.info	    sample_data
# data_reduced_raw.info  prediction.reduced.raw
# labels.reduced.raw     prediction.reduced.raw.info

# %%
data_xyz = HST_read("data_reduced.raw", dims=(256, 256, 256))

# %%
np.ndim(data_xyz) 
range(0,10,1)
# Out:
# range(0, 10)

# %%
reduced_data = data_xyz[0:2,0:2,0:2]
# Out:
# array([[[100, 106],
#         [107, 111]],
#
#        [[ 89,  92],
#         [ 87,  92]]], dtype=uint8)

# %%
np.zeros(2)
# Out:
# array([0., 0.])

# %%
M = data_xyz
A=[]

for i in range(256):
  for j in range(256):
    for k in range(256):
      A.append(M[i,j,k])

# %%
len(A)
# Out:
# 16777216

# %%
plt.style.use('fivethirtyeight')
plt.hist(A)
plt.title("Apparition des pixels")
plt.xlabel("Pixels de 0 à 255")
plt.ylabel("Nombre d'apparition")
# Out:
# Text(0, 0.5, "Nombre d'apparition")
